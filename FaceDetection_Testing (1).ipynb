# %%
#Karam Issa ;)

# !pip install opencv-python
# !pip install Pillow
# This will download the raw file from the opencv githup repo, to garuantee the file will always be uploaded correctly
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml

# %% [markdown]
# This code sets the KAGGLE_CONFIG_DIR environment variable to /content, which is a directory in the Google Colab environment. The KAGGLE_CONFIG_DIR environment variable is used by the Kaggle API client to locate the Kaggle configuration file that contains the user's Kaggle API credentials.
#
# By setting the KAGGLE_CONFIG_DIR environment variable to /content, you are telling the Kaggle API client to look for the Kaggle configuration file in the /content directory, which is where you can store the configuration file in the Colab environment. This is necessary for the Kaggle API client to work properly in Colab.
#
#
# **Dont forget to add your kaggle.json api key

# %%
#In the context of looping through a folder of images, we can use the os.listdir() function to get a list of all the files in the folder, and then use os.path.join() to construct the full path to each image file. This makes it easy to read and manipulate the images in the folder.
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content'

# %%
# !kaggle datasets download -d vin1234/count-the-number-of-faces-present-in-an-image

# %%
# !chmod 600 /content/kaggle.json

# %%
# !unzip \*.zip && rm*.zip

# %%
# Import the necessary libraries

# Used for opening and manipulating image files
from PIL import Image

# Used for makinf HTTP requests to web servers as the input image if from a URL
import requests

# Used for working with input and output streams.
from io import BytesIO
# Opencv Libraray fro image processing and computer vission
import cv2

# Used here to convert the image to/from a PIL Image object from/to a NumPy array.
import numpy as np

#The csv module provides classes for reading and writing CSV files, such as csv.reader, csv.writer, csv.DictReader, and csv.DictWriter. These classes provide methods and attributes for working with CSV files, such as iterating over rows, accessing columns by name, writing rows
import csv

# %% [markdown]
# This code iterates through each image file in the directory specified by image_path. It attempts to open each image file using the PIL library and skips over any files that cannot be opened. For each valid image file, it converts the image to a NumPy array that can be processed by OpenCV, loads a face detection classifier from a specified file path, and detects faces in the image using the detectMultiScale method. Finally, it writes a new row to the output CSV file with the filename and number of faces detected.

# %%
# Set the path to the directory containing the images
image_path = '/content/train/image_data/'


# Open the output CSV file for writing   
with open('output.csv', mode='w') as output_file:

  # Create a CSV writer object
  csv_writer = csv.writer(output_file)

  # Loop through each image file in the directory      
  for img in range(10001, 18208):
    
    # Construct the full path to the image file
    image_filename = str(img) + '.jpg'
    full_path = image_path + image_filename


    # Attempt to open the image file
    try:
      image = Image.open(full_path)
    except:
      # If there is an error opening the image file, skip it and move on to the next file
      continue
    else:
      # Convert the image to a NumPy array that can be processed by OpenCv
      image_array = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)



      # Load the face detection classifier from the specified file path
      face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
           

      # Convert the image to grayscale, which is required for face detection
      gray_image = cv2.cvtColor(image_array, cv2.COLOR_BGR2GRAY)

      # Detect faces in the image using the face detection classifier
      faces = face_cascade.detectMultiScale(gray_image, scaleFactor=1.05, minNeighbors=5)

      # Write a new row to the output CSV file with the filename and number of faces detected
      csv_writer.writerow([image_filename, len(faces)])

# %%
# Open the input file for reading
with open('output.csv', 'r') as input_file:
    reader = csv.reader(input_file)

    # Read in the data rows
    data = [row for row in reader]

# Insert a new header row at the beginning of the data
header_row = ['Name', 'HeadCount']
data.insert(0, header_row)

# Open the output file for writing
with open('output.csv', 'w', newline='') as output_file:
    writer = csv.writer(output_file)

    # Write out the data to the output file
    for row in data:
        writer.writerow(row)

# %% [markdown]
# This code compares the headcount values for each image in the train.csv file with the headcount values obtained from running face detection on the images and stored in the output.csv file.
#
# It does this by creating a dictionary headcount_dict that stores the headcount values for each file. It first reads through the train.csv file to get the filename and headcount value for each image. It then reads through the output.csv file to get the headcount value obtained from running face detection on each image. If a match is found between the filename in train.csv and output.csv, the headcount values for both are stored in the headcount_dict dictionary.
#
# Finally, the code prints out the headcount values for each file in the headcount_dict dictionary. If a file is not found in the output.csv file, a message is printed indicating that the file was not found.

# %%
# Open the train.csv file for reading
with open('/content/train/train.csv', 'r') as train_file:
    train_reader = csv.DictReader(train_file)

    # Open the output.csv file for reading
    with open('output.csv', 'r') as output_file:
        output_reader = csv.DictReader(output_file)

        # Create a dictionary to store the headcount values for each file
        headcount_dict = {}

        # Iterate over the rows in the train.csv file
        for train_row in train_reader:

            # Get the filename from the train row
            filename = train_row['Name']

            # Check if the filename is in the output.csv file
            for output_row in output_reader:
                if output_row['Name'] == filename:

                    # Store the headcount value for this file in the dictionary
                    headcount_dict[filename] = {
                        'train': int(train_row['HeadCount']),
                        'output': int(output_row['HeadCount'])
                    }

                    # Reset the output reader to the beginning of the file
                    output_file.seek(0)
                    next(output_reader)

                    # Break out of the inner loop since we found a match
                    break

            # If the filename wasn't found in the output.csv file, print a message
            else:
                print(f'File {filename} not found in output.csv')

# Print the headcount values for each file
for filename, counts in headcount_dict.items():
    print(f'{filename}: train={counts["train"]}, output={counts["output"]}')
# Out:
# Streaming output truncated to the last 5000 lines.
# 11074.jpg: train=4, output=3
# 11075.jpg: train=4, output=0
# 11076.jpg: train=7, output=3
# 11077.jpg: train=8, output=4
# 11078.jpg: train=8, output=4
# 11079.jpg: train=4, output=2
# 11083.jpg: train=7, output=6
# 11084.jpg: train=5, output=4
# 11085.jpg: train=8, output=7
# 11086.jpg: train=5, output=4
# 11087.jpg: train=4, output=0
# 11088.jpg: train=6, output=4
# 11090.jpg: train=7, output=8
# 11091.jpg: train=9, output=8
# 11092.jpg: train=5, output=5
# 11093.jpg: train=6, output=1
# 11095.jpg: train=5, output=4
# 11097.jpg: train=7, output=10
# 11098.jpg: train=2, output=1
# 11099.jpg: train=5, output=2
# 11100.jpg: train=6, output=2
# 11101.jpg: train=3, output=3
# 11104.jpg: train=3, output=4
# 11105.jpg: train=5, output=2
# 11108.jpg: train=6, output=6
# 11110.jpg: train=4, output=1
# 11111.jpg: train=4, output=3
# 11112.jpg: train=3, output=2
# 11113.jpg: train=7, output=5
# 11114.jpg: train=5, output=4
# 11119.jpg: train=12, output=6
# 11120.jpg: train=4, output=3
# 11121.jpg: train=4, output=3
# 11123.jpg: train=6, output=5
# 11125.jpg: train=4, output=3
# 11127.jpg: train=6, output=7
# 11129.jpg: train=11, output=12
# 11130.jpg: train=4, output=6
# 11132.jpg: train=4, output=0
# 11133.jpg: train=4, output=2
# 11135.jpg: train=5, output=6
# 11136.jpg: train=4, output=3
# 11137.jpg: train=5, output=3
# 11139.jpg: train=3, output=4
# 11142.jpg: train=6, output=5
# 11143.jpg: train=3, output=1
# 11144.jpg: train=5, output=1
# 11145.jpg: train=4, output=3
# 11146.jpg: train=5, output=3
# 11147.jpg: train=5, output=3
# 11148.jpg: train=5, output=5
# 11149.jpg: train=6, output=2
# 11151.jpg: train=4, output=3
# 11154.jpg: train=5, output=0
# 11155.jpg: train=5, output=0
# 11156.jpg: train=4, output=3
# 11157.jpg: train=7, output=3
# 11159.jpg: train=11, output=4
# 11160.jpg: train=5, output=5
# 11161.jpg: train=4, output=6
# 11162.jpg: train=6, output=0
# 11163.jpg: train=3, output=3
# 11165.jpg: train=3, output=5
# 11166.jpg: train=5, output=3
# 11169.jpg: train=5, output=3
# 11170.jpg: train=7, output=5
# 11171.jpg: train=5, output=4
# 11172.jpg: train=5, output=2
# 11173.jpg: train=5, output=3
# 11174.jpg: train=5, output=5
# 11175.jpg: train=4, output=5
# 11176.jpg: train=4, output=5
# 11177.jpg: train=5, output=7
# 11178.jpg: train=5, output=3
# 11179.jpg: train=3, output=4
# 11180.jpg: train=3, output=4
# 11182.jpg: train=3, output=0
# 11183.jpg: train=3, output=4
# 11184.jpg: train=4, output=6
# 11186.jpg: train=2, output=5
# 11187.jpg: train=2, output=1
# 11189.jpg: train=9, output=10
# 11191.jpg: train=2, output=4
# 11194.jpg: train=2, output=1
# 11195.jpg: train=2, output=2
# 11196.jpg: train=6, output=7
# 11197.jpg: train=6, output=5
# 11199.jpg: train=8, output=6
# 11200.jpg: train=4, output=3
# 11202.jpg: train=4, output=2
# 11203.jpg: train=4, output=4
# 11204.jpg: train=5, output=6
# 11205.jpg: train=5, output=5
# 11206.jpg: train=2, output=2
# 11210.jpg: train=4, output=5
# 11211.jpg: train=4, output=4
# 11212.jpg: train=4, output=7
# 11213.jpg: train=4, output=3
# 11214.jpg: train=5, output=6
# 11215.jpg: train=7, output=9
# 11218.jpg: train=3, output=3
# 11221.jpg: train=5, output=5
# 11223.jpg: train=2, output=5
# 11225.jpg: train=2, output=3
# 11226.jpg: train=8, output=8
# 11231.jpg: train=4, output=4
# 11233.jpg: train=4, output=5
# 11234.jpg: train=16, output=15
# 11235.jpg: train=5, output=6
# 11236.jpg: train=3, output=2
# 11237.jpg: train=3, output=1
# 11238.jpg: train=12, output=13
# 11241.jpg: train=5, output=7
# 11242.jpg: train=3, output=3
# 11243.jpg: train=4, output=2
# 11244.jpg: train=3, output=2
# 11245.jpg: train=5, output=1
# 11246.jpg: train=5, output=4
# 11247.jpg: train=3, output=3
# 11252.jpg: train=3, output=1
# 11254.jpg: train=3, output=2
# 11257.jpg: train=5, output=5
# 11258.jpg: train=2, output=2
# 11260.jpg: train=2, output=3
# 11262.jpg: train=2, output=2
# 11263.jpg: train=2, output=2
# 11264.jpg: train=4, output=3
# 11265.jpg: train=2, output=5
# 11266.jpg: train=5, output=4
# 11269.jpg: train=2, output=2
# 11272.jpg: train=4, output=5
# 11273.jpg: train=12, output=10
# 11274.jpg: train=3, output=4
# 11275.jpg: train=3, output=4
# 11276.jpg: train=2, output=1
# 11277.jpg: train=2, output=0
# 11278.jpg: train=2, output=3
# 11279.jpg: train=3, output=2
# 11280.jpg: train=2, output=1
# 11282.jpg: train=7, output=7
# 11283.jpg: train=6, output=8
# 11284.jpg: train=3, output=2
# 11287.jpg: train=2, output=0
# 11288.jpg: train=2, output=0
# 11289.jpg: train=2, output=0
# 11292.jpg: train=11, output=13
# 11293.jpg: train=2, output=3
# 11296.jpg: train=4, output=4
# 11297.jpg: train=3, output=4
# 11298.jpg: train=5, output=7
# 11299.jpg: train=12, output=10
# 11300.jpg: train=4, output=3
# 11301.jpg: train=5, output=3
# 11302.jpg: train=2, output=2
# 11304.jpg: train=2, output=2
# 11306.jpg: train=3, output=2
# 11307.jpg: train=3, output=2
# 11308.jpg: train=6, output=5
# 11309.jpg: train=7, output=8
# 11310.jpg: train=6, output=3
# 11311.jpg: train=7, output=8
# 11312.jpg: train=6, output=5
# 11313.jpg: train=6, output=5
# 11315.jpg: train=3, output=1
# 11316.jpg: train=3, output=2
# 11317.jpg: train=3, output=2
# 11318.jpg: train=3, output=4
# 11319.jpg: train=4, output=4
# 11320.jpg: train=6, output=4
# 11321.jpg: train=4, output=1
# 11322.jpg: train=2, output=4
# 11323.jpg: train=3, output=1
# 11324.jpg: train=1, output=2
# 11326.jpg: train=2, output=2
# 11327.jpg: train=4, output=4
# 11329.jpg: train=5, output=0
# 11330.jpg: train=4, output=5
# 11331.jpg: train=2, output=2
# 11332.jpg: train=5, output=5
# 11333.jpg: train=2, output=1
# 11334.jpg: train=4, output=6
# 11335.jpg: train=6, output=1
# 11336.jpg: train=4, output=2
# 11337.jpg: train=6, output=1
# 11338.jpg: train=6, output=3
# 11340.jpg: train=2, output=2
# 11341.jpg: train=2, output=6
# 11342.jpg: train=6, output=2
# 11343.jpg: train=4, output=2
# 11344.jpg: train=6, output=2
# 11346.jpg: train=6, output=3
# 11347.jpg: train=6, output=0
# 11348.jpg: train=4, output=5
# 11349.jpg: train=3, output=3
# 11350.jpg: train=6, output=2
# 11351.jpg: train=11, output=7
# 11352.jpg: train=2, output=2
# 11355.jpg: train=5, output=5
# 11356.jpg: train=2, output=1
# 11357.jpg: train=3, output=3
# 11359.jpg: train=3, output=3
# 11360.jpg: train=3, output=7
# 11361.jpg: train=3, output=2
# 11362.jpg: train=1, output=1
# 11363.jpg: train=5, output=3
# 11365.jpg: train=4, output=4
# 11366.jpg: train=7, output=6
# 11367.jpg: train=2, output=2
# 11368.jpg: train=5, output=6
# 11369.jpg: train=4, output=6
# 11370.jpg: train=4, output=3
# 11371.jpg: train=4, output=3
# 11372.jpg: train=4, output=4
# 11375.jpg: train=3, output=3
# 11376.jpg: train=7, output=5
# 11379.jpg: train=8, output=1
# 11380.jpg: train=6, output=8
# 11382.jpg: train=4, output=3
# 11387.jpg: train=5, output=5
# 11388.jpg: train=3, output=3
# 11389.jpg: train=3, output=2
# 11391.jpg: train=3, output=3
# 11392.jpg: train=3, output=2
# 11393.jpg: train=3, output=2
# 11395.jpg: train=2, output=3
# 11396.jpg: train=4, output=4
# 11397.jpg: train=4, output=2
# 11399.jpg: train=11, output=8
# 11400.jpg: train=4, output=5
# 11402.jpg: train=3, output=4
# 11403.jpg: train=4, output=5
# 11404.jpg: train=4, output=0
# 11405.jpg: train=3, output=1
# 11406.jpg: train=4, output=3
# 11407.jpg: train=2, output=0
# 11408.jpg: train=3, output=2
# 11412.jpg: train=2, output=2
# 11413.jpg: train=2, output=4
# 11415.jpg: train=3, output=1
# 11416.jpg: train=3, output=1
# 11417.jpg: train=3, output=3
# 11418.jpg: train=4, output=2
# 11419.jpg: train=4, output=3
# 11422.jpg: train=6, output=1
# 11423.jpg: train=2, output=1
# 11425.jpg: train=3, output=3
# 11426.jpg: train=3, output=2
# 11427.jpg: train=3, output=3
# 11428.jpg: train=2, output=4
# 11429.jpg: train=4, output=7
# 11430.jpg: train=3, output=4
# 11431.jpg: train=4, output=1
# 11432.jpg: train=3, output=2
# 11433.jpg: train=3, output=3
# 11434.jpg: train=6, output=6
# 11435.jpg: train=2, output=0
# 11436.jpg: train=5, output=3
# 11437.jpg: train=5, output=5
# 11439.jpg: train=5, output=1
# 11440.jpg: train=3, output=2
# 11442.jpg: train=2, output=3
# 11443.jpg: train=3, output=3
# 11444.jpg: train=3, output=2
# 11445.jpg: train=3, output=4
# 11446.jpg: train=6, output=4
# 11448.jpg: train=3, output=4
# 11449.jpg: train=9, output=5
# 11452.jpg: train=6, output=4
# 11453.jpg: train=6, output=5
# 11454.jpg: train=5, output=3
# 11457.jpg: train=4, output=2
# 11458.jpg: train=2, output=0
# 11459.jpg: train=3, output=5
# 11460.jpg: train=2, output=1
# 11465.jpg: train=3, output=3
# 11466.jpg: train=5, output=1
# 11467.jpg: train=2, output=2
# 11468.jpg: train=2, output=1
# 11469.jpg: train=4, output=2
# 11471.jpg: train=2, output=2
# 11472.jpg: train=2, output=3
# 11475.jpg: train=5, output=1
# 11476.jpg: train=6, output=1
# 11477.jpg: train=5, output=8
# 11479.jpg: train=3, output=0
# 11480.jpg: train=3, output=4
# 11482.jpg: train=2, output=2
# 11483.jpg: train=7, output=7
# 11484.jpg: train=7, output=7
# 11485.jpg: train=3, output=0
# 11486.jpg: train=5, output=0
# 11487.jpg: train=4, output=4
# 11488.jpg: train=3, output=3
# 11489.jpg: train=3, output=4
# 11491.jpg: train=2, output=3
# 11492.jpg: train=2, output=2
# 11493.jpg: train=3, output=1
# 11494.jpg: train=6, output=6
# 11496.jpg: train=4, output=3
# 11499.jpg: train=2, output=2
# 11500.jpg: train=3, output=2
# 11502.jpg: train=2, output=2
# 11503.jpg: train=5, output=5
# 11504.jpg: train=2, output=1
# 11505.jpg: train=3, output=3
# 11507.jpg: train=3, output=3
# 11508.jpg: train=17, output=18
# 11509.jpg: train=7, output=5
# 11511.jpg: train=3, output=3
# 11512.jpg: train=2, output=2
# 11513.jpg: train=2, output=2
# 11514.jpg: train=2, output=2
# 11515.jpg: train=4, output=4
# 11517.jpg: train=2, output=1
# 11518.jpg: train=2, output=1
# 11519.jpg: train=2, output=6
# 11520.jpg: train=2, output=1
# 11521.jpg: train=2, output=2
# 11522.jpg: train=2, output=2
# 11523.jpg: train=2, output=1
# 11525.jpg: train=3, output=2
# 11526.jpg: train=6, output=3
# 11528.jpg: train=2, output=2
# 11530.jpg: train=2, output=3
# 11531.jpg: train=2, output=2
# 11532.jpg: train=4, output=1
# 11533.jpg: train=3, output=3
# 11534.jpg: train=3, output=2
# 11535.jpg: train=4, output=2
# 11538.jpg: train=2, output=2
# 11540.jpg: train=2, output=2
# 11542.jpg: train=2, output=2
# 11544.jpg: train=2, output=1
# 11546.jpg: train=2, output=1
# 11547.jpg: train=2, output=1
# 11549.jpg: train=2, output=4
# 11551.jpg: train=2, output=2
# 11552.jpg: train=2, output=2
# 11553.jpg: train=2, output=4
# 11554.jpg: train=2, output=1
# 11555.jpg: train=2, output=2
# 11556.jpg: train=2, output=2
# 11557.jpg: train=2, output=2
# 11558.jpg: train=4, output=5
# 11559.jpg: train=4, output=2
# 11561.jpg: train=2, output=2
# 11562.jpg: train=2, output=0
# 11564.jpg: train=2, output=1
# 11565.jpg: train=2, output=1
# 11567.jpg: train=2, output=2
# 11569.jpg: train=4, output=3
# 11570.jpg: train=4, output=2
# 11572.jpg: train=2, output=1
# 11574.jpg: train=2, output=3
# 11575.jpg: train=3, output=4
# 11576.jpg: train=4, output=2
# 11578.jpg: train=4, output=0
# 11579.jpg: train=3, output=3
# 11581.jpg: train=4, output=4
# 11582.jpg: train=8, output=9
# 11583.jpg: train=6, output=6
# 11584.jpg: train=6, output=7
# 11586.jpg: train=2, output=8
# 11587.jpg: train=3, output=2
# 11588.jpg: train=6, output=4
# 11591.jpg: train=5, output=6
# 11592.jpg: train=5, output=2
# 11594.jpg: train=5, output=5
# 11595.jpg: train=3, output=3
# 11596.jpg: train=5, output=4
# 11598.jpg: train=3, output=4
# 11600.jpg: train=7, output=8
# 11602.jpg: train=6, output=3
# 11603.jpg: train=5, output=3
# 11604.jpg: train=6, output=6
# 11605.jpg: train=4, output=4
# 11606.jpg: train=5, output=6
# 11607.jpg: train=2, output=4
# 11608.jpg: train=2, output=1
# 11610.jpg: train=4, output=4
# 11612.jpg: train=2, output=2
# 11613.jpg: train=2, output=3
# 11614.jpg: train=2, output=2
# 11615.jpg: train=3, output=2
# 11616.jpg: train=5, output=5
# 11617.jpg: train=3, output=1
# 11618.jpg: train=7, output=5
# 11619.jpg: train=2, output=2
# 11620.jpg: train=5, output=5
# 11621.jpg: train=5, output=5
# 11622.jpg: train=4, output=1
# 11623.jpg: train=5, output=4
# 11624.jpg: train=5, output=2
# 11625.jpg: train=3, output=5
# 11628.jpg: train=4, output=5
# 11630.jpg: train=6, output=4
# 11631.jpg: train=3, output=2
# 11632.jpg: train=2, output=3
# 11633.jpg: train=3, output=5
# 11635.jpg: train=4, output=5
# 11636.jpg: train=6, output=3
# 11637.jpg: train=5, output=5
# 11638.jpg: train=3, output=4
# 11639.jpg: train=3, output=3
# 11640.jpg: train=8, output=8
# 11641.jpg: train=8, output=10
# 11643.jpg: train=3, output=1
# 11644.jpg: train=4, output=2
# 11645.jpg: train=3, output=2
# 11646.jpg: train=2, output=4
# 11647.jpg: train=6, output=6
# 11649.jpg: train=5, output=5
# 11651.jpg: train=7, output=8
# 11652.jpg: train=4, output=2
# 11653.jpg: train=2, output=2
# 11654.jpg: train=4, output=2
# 11655.jpg: train=2, output=1
# 11656.jpg: train=2, output=2
# 11661.jpg: train=4, output=1
# 11662.jpg: train=6, output=4
# 11663.jpg: train=6, output=8
# 11664.jpg: train=6, output=3
# 11665.jpg: train=6, output=4
# 11667.jpg: train=5, output=5
# 11668.jpg: train=4, output=3
# 11671.jpg: train=2, output=1
# 11672.jpg: train=5, output=9
# 11673.jpg: train=3, output=0
# 11674.jpg: train=3, output=2
# 11675.jpg: train=5, output=4
# 11676.jpg: train=8, output=6
# 11677.jpg: train=6, output=5
# 11678.jpg: train=5, output=5
# 11679.jpg: train=5, output=3
# 11681.jpg: train=5, output=3
# 11682.jpg: train=4, output=1
# 11684.jpg: train=4, output=3
# 11685.jpg: train=5, output=2
# 11686.jpg: train=5, output=2
# 11687.jpg: train=5, output=2
# 11688.jpg: train=5, output=4
# 11689.jpg: train=5, output=4
# 11690.jpg: train=12, output=1
# 11691.jpg: train=18, output=8
# 11692.jpg: train=20, output=5
# 11693.jpg: train=5, output=3
# 11696.jpg: train=10, output=4
# 11697.jpg: train=5, output=5
# 11699.jpg: train=4, output=3
# 11700.jpg: train=9, output=7
# 11702.jpg: train=4, output=0
# 11703.jpg: train=4, output=2
# 11704.jpg: train=4, output=1
# 11707.jpg: train=3, output=0
# 11708.jpg: train=3, output=6
# 11709.jpg: train=4, output=5
# 11710.jpg: train=4, output=1
# 11712.jpg: train=3, output=2
# 11713.jpg: train=3, output=4
# 11714.jpg: train=3, output=2
# 11716.jpg: train=2, output=3
# 11717.jpg: train=2, output=3
# 11718.jpg: train=3, output=4
# 11721.jpg: train=2, output=0
# 11722.jpg: train=6, output=1
# 11723.jpg: train=4, output=3
# 11724.jpg: train=4, output=3
# 11725.jpg: train=4, output=5
# 11726.jpg: train=4, output=2
# 11727.jpg: train=4, output=5
# 11728.jpg: train=4, output=4
# 11729.jpg: train=4, output=5
# 11732.jpg: train=4, output=2
# 11733.jpg: train=3, output=2
# 11734.jpg: train=4, output=3
# 11736.jpg: train=5, output=1
# 11738.jpg: train=13, output=10
# 11739.jpg: train=4, output=5
# 11740.jpg: train=2, output=6
# 11741.jpg: train=2, output=1
# 11745.jpg: train=4, output=3
# 11746.jpg: train=4, output=4
# 11748.jpg: train=7, output=7
# 11749.jpg: train=4, output=3
# 11750.jpg: train=3, output=2
# 11751.jpg: train=6, output=3
# 11754.jpg: train=2, output=2
# 11755.jpg: train=3, output=3
# 11756.jpg: train=5, output=5
# 11758.jpg: train=4, output=3
# 11759.jpg: train=3, output=5
# 11760.jpg: train=5, output=4
# 11761.jpg: train=2, output=3
# 11763.jpg: train=2, output=2
# 11764.jpg: train=3, output=2
# 11765.jpg: train=4, output=4
# 11766.jpg: train=9, output=4
# 11768.jpg: train=4, output=3
# 11769.jpg: train=2, output=1
# 11772.jpg: train=5, output=4
# 11774.jpg: train=4, output=3
# 11775.jpg: train=11, output=8
# 11776.jpg: train=2, output=1
# 11777.jpg: train=3, output=3
# 11779.jpg: train=3, output=2
# 11780.jpg: train=5, output=5
# 11781.jpg: train=1, output=1
# 11782.jpg: train=6, output=6
# 11783.jpg: train=2, output=2
# 11784.jpg: train=10, output=8
# 11786.jpg: train=3, output=0
# 11787.jpg: train=3, output=2
# 11788.jpg: train=5, output=4
# 11789.jpg: train=4, output=5
# 11793.jpg: train=6, output=7
# 11795.jpg: train=3, output=5
# 11796.jpg: train=5, output=6
# 11798.jpg: train=5, output=6
# 11799.jpg: train=4, output=6
# 11800.jpg: train=4, output=1
# 11802.jpg: train=5, output=6
# 11803.jpg: train=6, output=6
# 11804.jpg: train=4, output=1
# 11805.jpg: train=6, output=2
# 11806.jpg: train=2, output=0
# 11807.jpg: train=3, output=2
# 11808.jpg: train=2, output=2
# 11809.jpg: train=3, output=2
# 11810.jpg: train=1, output=2
# 11811.jpg: train=1, output=1
# 11812.jpg: train=1, output=1
# 11813.jpg: train=2, output=2
# 11814.jpg: train=2, output=3
# 11815.jpg: train=2, output=0
# 11816.jpg: train=3, output=2
# 11817.jpg: train=3, output=3
# 11818.jpg: train=4, output=4
# 11820.jpg: train=6, output=3
# 11821.jpg: train=7, output=4
# 11822.jpg: train=3, output=3
# 11824.jpg: train=2, output=0
# 11825.jpg: train=2, output=2
# 11827.jpg: train=2, output=0
# 11830.jpg: train=3, output=4
# 11832.jpg: train=3, output=3
# 11833.jpg: train=4, output=3
# 11835.jpg: train=3, output=5
# 11840.jpg: train=3, output=3
# 11841.jpg: train=5, output=6
# 11844.jpg: train=5, output=3
# 11845.jpg: train=5, output=5
# 11851.jpg: train=5, output=2
# 11854.jpg: train=8, output=3
# 11855.jpg: train=3, output=4
# 11856.jpg: train=3, output=5
# 11858.jpg: train=3, output=3
# 11860.jpg: train=8, output=8
# 11861.jpg: train=3, output=2
# 11862.jpg: train=3, output=3
# 11863.jpg: train=2, output=1
# 11864.jpg: train=2, output=2
# 11865.jpg: train=2, output=4
# 11866.jpg: train=2, output=2
# 11867.jpg: train=2, output=1
# 11868.jpg: train=2, output=1
# 11870.jpg: train=4, output=1
# 11871.jpg: train=2, output=1
# 11872.jpg: train=8, output=3
# 11873.jpg: train=2, output=1
# 11875.jpg: train=3, output=2
# 11877.jpg: train=5, output=2
# 11878.jpg: train=2, output=1
# 11879.jpg: train=1, output=0
# 11883.jpg: train=2, output=2
# 11884.jpg: train=6, output=4
# 11885.jpg: train=3, output=6
# 11887.jpg: train=5, output=1
# 11889.jpg: train=2, output=2
# 11891.jpg: train=2, output=1
# 11894.jpg: train=3, output=4
# 11895.jpg: train=5, output=4
# 11896.jpg: train=5, output=4
# 11897.jpg: train=2, output=3
# 11900.jpg: train=3, output=4
# 11904.jpg: train=3, output=4
# 11905.jpg: train=4, output=6
# 11906.jpg: train=2, output=2
# 11907.jpg: train=2, output=0
# 11908.jpg: train=4, output=4
# 11909.jpg: train=4, output=1
# 11911.jpg: train=2, output=2
# 11912.jpg: train=1, output=2
# 11913.jpg: train=13, output=8
# 11914.jpg: train=6, output=5
# 11915.jpg: train=3, output=4
# 11919.jpg: train=6, output=7
# 11921.jpg: train=5, output=5
# 11922.jpg: train=5, output=2
# 11923.jpg: train=5, output=6
# 11925.jpg: train=2, output=2
# 11927.jpg: train=3, output=1
# 11929.jpg: train=6, output=7
# 11930.jpg: train=3, output=1
# 11932.jpg: train=5, output=4
# 11933.jpg: train=3, output=4
# 11935.jpg: train=4, output=3
# 11937.jpg: train=4, output=3
# 11938.jpg: train=4, output=4
# 11939.jpg: train=2, output=1
# 11940.jpg: train=5, output=6
# 11943.jpg: train=3, output=3
# 11944.jpg: train=8, output=4
# 11945.jpg: train=3, output=3
# 11946.jpg: train=6, output=8
# 11947.jpg: train=8, output=7
# 11948.jpg: train=3, output=5
# 11949.jpg: train=2, output=3
# 11950.jpg: train=2, output=2
# 11951.jpg: train=2, output=2
# 11952.jpg: train=5, output=6
# 11953.jpg: train=3, output=3
# 11954.jpg: train=2, output=2
# 11955.jpg: train=2, output=4
# 11956.jpg: train=2, output=1
# 11957.jpg: train=6, output=3
# 11958.jpg: train=4, output=2
# 11960.jpg: train=2, output=2
# 11961.jpg: train=1, output=1
# 11962.jpg: train=5, output=3
# 11963.jpg: train=1, output=0
# 11964.jpg: train=3, output=3
# 11965.jpg: train=4, output=4
# 11967.jpg: train=6, output=3
# 11970.jpg: train=2, output=2
# 11972.jpg: train=2, output=2
# 11973.jpg: train=2, output=2
# 11975.jpg: train=6, output=6
# 11976.jpg: train=7, output=4
# 11977.jpg: train=7, output=3
# 11978.jpg: train=3, output=1
# 11979.jpg: train=5, output=3
# 11981.jpg: train=4, output=6
# 11982.jpg: train=4, output=5
# 11983.jpg: train=2, output=3
# 11985.jpg: train=5, output=8
# 11990.jpg: train=11, output=5
# 11991.jpg: train=3, output=1
# 11992.jpg: train=2, output=2
# 11994.jpg: train=2, output=3
# 11995.jpg: train=2, output=2
# 11996.jpg: train=2, output=4
# 11997.jpg: train=3, output=3
# 11998.jpg: train=6, output=11
# 11999.jpg: train=3, output=0
# 12001.jpg: train=4, output=1
# 12002.jpg: train=2, output=0
# 12003.jpg: train=4, output=3
# 12006.jpg: train=4, output=6
# 12007.jpg: train=6, output=5
# 12008.jpg: train=5, output=6
# 12009.jpg: train=4, output=5
# 12011.jpg: train=4, output=4
# 12012.jpg: train=4, output=5
# 12015.jpg: train=6, output=3
# 12018.jpg: train=2, output=4
# 12019.jpg: train=3, output=2
# 12021.jpg: train=8, output=4
# 12022.jpg: train=4, output=1
# 12027.jpg: train=4, output=4
# 12028.jpg: train=4, output=4
# 12029.jpg: train=5, output=6
# 12030.jpg: train=3, output=0
# 12035.jpg: train=3, output=3
# 12037.jpg: train=3, output=2
# 12040.jpg: train=5, output=5
# 12041.jpg: train=6, output=5
# 12042.jpg: train=8, output=9
# 12044.jpg: train=3, output=2
# 12045.jpg: train=3, output=5
# 12047.jpg: train=2, output=2
# 12048.jpg: train=2, output=2
# 12050.jpg: train=6, output=3
# 12051.jpg: train=5, output=2
# 12053.jpg: train=2, output=1
# 12055.jpg: train=2, output=1
# 12056.jpg: train=3, output=2
# 12057.jpg: train=4, output=4
# 12058.jpg: train=4, output=4
# 12059.jpg: train=3, output=4
# 12060.jpg: train=5, output=2
# 12061.jpg: train=3, output=2
# 12064.jpg: train=3, output=4
# 12065.jpg: train=8, output=4
# 12066.jpg: train=5, output=1
# 12069.jpg: train=5, output=2
# 12070.jpg: train=4, output=3
# 12072.jpg: train=4, output=4
# 12073.jpg: train=3, output=4
# 12074.jpg: train=2, output=2
# 12075.jpg: train=5, output=4
# 12076.jpg: train=3, output=2
# 12077.jpg: train=4, output=3
# 12078.jpg: train=5, output=3
# 12079.jpg: train=5, output=6
# 12080.jpg: train=5, output=6
# 12081.jpg: train=4, output=4
# 12082.jpg: train=4, output=5
# 12084.jpg: train=3, output=3
# 12085.jpg: train=2, output=3
# 12086.jpg: train=4, output=3
# 12087.jpg: train=3, output=1
# 12088.jpg: train=3, output=2
# 12089.jpg: train=4, output=4
# 12090.jpg: train=5, output=6
# 12091.jpg: train=5, output=2
# 12092.jpg: train=9, output=4
# 12093.jpg: train=5, output=3
# 12095.jpg: train=2, output=5
# 12096.jpg: train=2, output=1
# 12097.jpg: train=2, output=1
# 12099.jpg: train=3, output=0
# 12100.jpg: train=8, output=4
# 12101.jpg: train=8, output=4
# 12103.jpg: train=8, output=7
# 12107.jpg: train=5, output=5
# 12108.jpg: train=4, output=6
# 12109.jpg: train=2, output=2
# 12112.jpg: train=3, output=2
# 12113.jpg: train=3, output=5
# 12114.jpg: train=5, output=7
# 12116.jpg: train=9, output=11
# 12118.jpg: train=4, output=4
# 12121.jpg: train=2, output=2
# 12123.jpg: train=4, output=3
# 12126.jpg: train=3, output=2
# 12128.jpg: train=3, output=4
# 12130.jpg: train=6, output=4
# 12131.jpg: train=5, output=1
# 12132.jpg: train=4, output=3
# 12133.jpg: train=4, output=3
# 12134.jpg: train=4, output=3
# 12135.jpg: train=4, output=2
# 12139.jpg: train=8, output=4
# 12140.jpg: train=3, output=3
# 12141.jpg: train=6, output=4
# 12143.jpg: train=4, output=4
# 12144.jpg: train=4, output=4
# 12146.jpg: train=2, output=2
# 12147.jpg: train=5, output=6
# 12149.jpg: train=2, output=2
# 12150.jpg: train=4, output=1
# 12151.jpg: train=4, output=4
# 12152.jpg: train=8, output=10
# 12153.jpg: train=2, output=2
# 12154.jpg: train=3, output=3
# 12155.jpg: train=6, output=8
# 12156.jpg: train=5, output=1
# 12157.jpg: train=3, output=0
# 12159.jpg: train=2, output=4
# 12160.jpg: train=2, output=0
# 12163.jpg: train=3, output=5
# 12165.jpg: train=5, output=5
# 12167.jpg: train=5, output=8
# 12168.jpg: train=7, output=7
# 12169.jpg: train=5, output=7
# 12170.jpg: train=6, output=7
# 12171.jpg: train=5, output=6
# 12172.jpg: train=4, output=2
# 12173.jpg: train=6, output=5
# 12174.jpg: train=5, output=2
# 12175.jpg: train=4, output=2
# 12178.jpg: train=6, output=4
# 12181.jpg: train=2, output=1
# 12182.jpg: train=7, output=5
# 12184.jpg: train=3, output=3
# 12185.jpg: train=3, output=4
# 12187.jpg: train=3, output=5
# 12191.jpg: train=3, output=3
# 12195.jpg: train=5, output=5
# 12197.jpg: train=6, output=6
# 12198.jpg: train=5, output=2
# 12199.jpg: train=3, output=3
# 12200.jpg: train=6, output=3
# 12201.jpg: train=9, output=7
# 12202.jpg: train=3, output=2
# 12203.jpg: train=4, output=5
# 12204.jpg: train=5, output=3
# 12205.jpg: train=2, output=3
# 12206.jpg: train=4, output=5
# 12207.jpg: train=6, output=2
# 12208.jpg: train=5, output=0
# 12211.jpg: train=4, output=5
# 12212.jpg: train=6, output=2
# 12213.jpg: train=5, output=5
# 12215.jpg: train=5, output=5
# 12216.jpg: train=4, output=5
# 12219.jpg: train=3, output=4
# 12220.jpg: train=4, output=3
# 12221.jpg: train=6, output=6
# 12222.jpg: train=11, output=3
# 12223.jpg: train=5, output=3
# 12225.jpg: train=4, output=3
# 12226.jpg: train=8, output=4
# 12227.jpg: train=5, output=5
# 12228.jpg: train=6, output=1
# 12229.jpg: train=3, output=3
# 12231.jpg: train=4, output=5
# 12232.jpg: train=3, output=3
# 12233.jpg: train=5, output=10
# 12237.jpg: train=5, output=5
# 12239.jpg: train=4, output=4
# 12242.jpg: train=3, output=3
# 12243.jpg: train=3, output=2
# 12244.jpg: train=3, output=2
# 12246.jpg: train=3, output=1
# 12247.jpg: train=3, output=3
# 12248.jpg: train=3, output=2
# 12249.jpg: train=3, output=3
# 12250.jpg: train=3, output=3
# 12252.jpg: train=3, output=0
# 12253.jpg: train=3, output=2
# 12254.jpg: train=6, output=6
# 12256.jpg: train=3, output=4
# 12257.jpg: train=3, output=3
# 12258.jpg: train=5, output=5
# 12261.jpg: train=6, output=8
# 12262.jpg: train=3, output=2
# 12263.jpg: train=3, output=3
# 12265.jpg: train=3, output=0
# 12267.jpg: train=3, output=4
# 12269.jpg: train=3, output=3
# 12271.jpg: train=3, output=2
# 12272.jpg: train=3, output=3
# 12274.jpg: train=3, output=0
# 12275.jpg: train=3, output=3
# 12276.jpg: train=3, output=4
# 12277.jpg: train=3, output=3
# 12279.jpg: train=3, output=1
# 12280.jpg: train=3, output=4
# 12281.jpg: train=3, output=4
# 12282.jpg: train=3, output=3
# 12283.jpg: train=3, output=0
# 12285.jpg: train=3, output=3
# 12287.jpg: train=3, output=2
# 12288.jpg: train=3, output=2
# 12289.jpg: train=3, output=5
# 12290.jpg: train=3, output=6
# 12291.jpg: train=3, output=2
# 12293.jpg: train=3, output=2
# 12295.jpg: train=3, output=2
# 12297.jpg: train=3, output=5
# 12298.jpg: train=3, output=4
# 12299.jpg: train=3, output=3
# 12300.jpg: train=3, output=2
# 12301.jpg: train=5, output=3
# 12303.jpg: train=6, output=3
# 12304.jpg: train=3, output=3
# 12306.jpg: train=3, output=5
# 12307.jpg: train=3, output=1
# 12308.jpg: train=3, output=2
# 12309.jpg: train=3, output=3
# 12310.jpg: train=4, output=3
# 12311.jpg: train=3, output=4
# 12313.jpg: train=3, output=3
# 12314.jpg: train=5, output=4
# 12315.jpg: train=4, output=3
# 12317.jpg: train=2, output=2
# 12319.jpg: train=5, output=5
# 12320.jpg: train=3, output=3
# 12321.jpg: train=3, output=3
# 12324.jpg: train=4, output=3
# 12325.jpg: train=2, output=3
# 12326.jpg: train=3, output=0
# 12329.jpg: train=3, output=2
# 12332.jpg: train=4, output=2
# 12335.jpg: train=4, output=4
# 12336.jpg: train=8, output=3
# 12337.jpg: train=8, output=4
# 12338.jpg: train=2, output=2
# 12340.jpg: train=4, output=2
# 12341.jpg: train=2, output=1
# 12342.jpg: train=2, output=2
# 12344.jpg: train=2, output=2
# 12345.jpg: train=2, output=2
# 12346.jpg: train=2, output=3
# 12347.jpg: train=2, output=3
# 12348.jpg: train=4, output=3
# 12349.jpg: train=4, output=1
# 12350.jpg: train=4, output=3
# 12351.jpg: train=6, output=11
# 12352.jpg: train=4, output=1
# 12353.jpg: train=2, output=1
# 12354.jpg: train=5, output=4
# 12356.jpg: train=2, output=1
# 12358.jpg: train=2, output=2
# 12359.jpg: train=2, output=2
# 12360.jpg: train=2, output=0
# 12362.jpg: train=2, output=2
# 12364.jpg: train=2, output=3
# 12366.jpg: train=4, output=1
# 12367.jpg: train=2, output=1
# 12368.jpg: train=2, output=3
# 12370.jpg: train=2, output=2
# 12371.jpg: train=2, output=1
# 12372.jpg: train=2, output=0
# 12373.jpg: train=2, output=2
# 12374.jpg: train=4, output=2
# 12375.jpg: train=2, output=2
# 12378.jpg: train=3, output=2
# 12379.jpg: train=4, output=4
# 12380.jpg: train=2, output=3
# 12381.jpg: train=2, output=2
# 12382.jpg: train=2, output=1
# 12383.jpg: train=3, output=3
# 12385.jpg: train=2, output=2
# 12386.jpg: train=2, output=3
# 12387.jpg: train=2, output=1
# 12390.jpg: train=2, output=2
# 12391.jpg: train=2, output=3
# 12392.jpg: train=2, output=1
# 12394.jpg: train=2, output=3
# 12396.jpg: train=2, output=3
# 12397.jpg: train=2, output=1
# 12398.jpg: train=2, output=1
# 12399.jpg: train=2, output=2
# 12401.jpg: train=2, output=3
# 12402.jpg: train=2, output=1
# 12403.jpg: train=4, output=2
# 12405.jpg: train=2, output=2
# 12407.jpg: train=2, output=3
# 12408.jpg: train=3, output=1
# 12409.jpg: train=3, output=3
# 12410.jpg: train=2, output=2
# 12412.jpg: train=4, output=1
# 12413.jpg: train=3, output=1
# 12414.jpg: train=4, output=4
# 12416.jpg: train=4, output=5
# 12417.jpg: train=4, output=4
# 12418.jpg: train=2, output=2
# 12419.jpg: train=3, output=1
# 12420.jpg: train=3, output=2
# 12421.jpg: train=2, output=2
# 12422.jpg: train=5, output=4
# 12423.jpg: train=3, output=4
# 12424.jpg: train=5, output=5
# 12425.jpg: train=5, output=5
# 12426.jpg: train=6, output=7
# 12427.jpg: train=5, output=7
# 12429.jpg: train=3, output=1
# 12431.jpg: train=2, output=4
# 12432.jpg: train=4, output=1
# 12433.jpg: train=2, output=3
# 12435.jpg: train=5, output=0
# 12436.jpg: train=6, output=5
# 12437.jpg: train=4, output=4
# 12438.jpg: train=10, output=10
# 12439.jpg: train=5, output=5
# 12441.jpg: train=5, output=5
# 12444.jpg: train=3, output=5
# 12447.jpg: train=10, output=10
# 12448.jpg: train=5, output=1
# 12449.jpg: train=2, output=2
# 12450.jpg: train=6, output=2
# 12451.jpg: train=5, output=6
# 12452.jpg: train=2, output=2
# 12453.jpg: train=3, output=4
# 12454.jpg: train=6, output=3
# 12457.jpg: train=8, output=2
# 12458.jpg: train=7, output=4
# 12459.jpg: train=7, output=2
# 12460.jpg: train=8, output=5
# 12461.jpg: train=7, output=3
# 12463.jpg: train=7, output=7
# 12464.jpg: train=3, output=3
# 12467.jpg: train=5, output=3
# 12468.jpg: train=2, output=1
# 12470.jpg: train=3, output=1
# 12471.jpg: train=2, output=5
# 12473.jpg: train=3, output=2
# 12474.jpg: train=2, output=2
# 12476.jpg: train=2, output=2
# 12477.jpg: train=3, output=3
# 12478.jpg: train=6, output=8
# 12479.jpg: train=3, output=5
# 12480.jpg: train=2, output=2
# 12481.jpg: train=2, output=3
# 12483.jpg: train=7, output=5
# 12484.jpg: train=3, output=1
# 12485.jpg: train=4, output=3
# 12486.jpg: train=2, output=1
# 12487.jpg: train=3, output=2
# 12490.jpg: train=4, output=2
# 12491.jpg: train=3, output=4
# 12492.jpg: train=2, output=3
# 12493.jpg: train=2, output=2
# 12494.jpg: train=2, output=0
# 12496.jpg: train=2, output=2
# 12497.jpg: train=2, output=2
# 12498.jpg: train=2, output=0
# 12499.jpg: train=2, output=3
# 12500.jpg: train=3, output=3
# 12501.jpg: train=3, output=2
# 12502.jpg: train=4, output=3
# 12504.jpg: train=2, output=2
# 12505.jpg: train=4, output=5
# 12506.jpg: train=5, output=3
# 12507.jpg: train=7, output=4
# 12508.jpg: train=1, output=0
# 12511.jpg: train=5, output=4
# 12512.jpg: train=4, output=4
# 12513.jpg: train=3, output=5
# 12515.jpg: train=2, output=6
# 12517.jpg: train=5, output=2
# 12518.jpg: train=3, output=3
# 12519.jpg: train=5, output=6
# 12520.jpg: train=3, output=3
# 12521.jpg: train=5, output=4
# 12522.jpg: train=3, output=4
# 12523.jpg: train=2, output=1
# 12524.jpg: train=2, output=3
# 12525.jpg: train=4, output=2
# 12528.jpg: train=2, output=1
# 12529.jpg: train=4, output=2
# 12530.jpg: train=2, output=2
# 12531.jpg: train=2, output=2
# 12532.jpg: train=2, output=1
# 12533.jpg: train=4, output=5
# 12534.jpg: train=2, output=2
# 12536.jpg: train=2, output=2
# 12537.jpg: train=2, output=4
# 12538.jpg: train=2, output=2
# 12542.jpg: train=2, output=2
# 12543.jpg: train=3, output=3
# 12544.jpg: train=3, output=3
# 12545.jpg: train=3, output=3
# 12546.jpg: train=3, output=3
# 12549.jpg: train=3, output=3
# 12551.jpg: train=3, output=3
# 12552.jpg: train=1, output=1
# 12554.jpg: train=3, output=3
# 12557.jpg: train=4, output=3
# 12558.jpg: train=3, output=0
# 12560.jpg: train=5, output=6
# 12561.jpg: train=3, output=2
# 12562.jpg: train=3, output=3
# 12563.jpg: train=3, output=2
# 12564.jpg: train=3, output=1
# 12566.jpg: train=11, output=4
# 12567.jpg: train=5, output=4
# 12568.jpg: train=3, output=3
# 12569.jpg: train=3, output=2
# 12570.jpg: train=3, output=1
# 12571.jpg: train=3, output=0
# 12572.jpg: train=3, output=2
# 12573.jpg: train=3, output=4
# 12574.jpg: train=11, output=1
# 12577.jpg: train=2, output=3
# 12579.jpg: train=2, output=0
# 12580.jpg: train=2, output=1
# 12584.jpg: train=4, output=2
# 12585.jpg: train=4, output=1
# 12587.jpg: train=3, output=2
# 12588.jpg: train=4, output=2
# 12591.jpg: train=5, output=5
# 12593.jpg: train=5, output=1
# 12594.jpg: train=4, output=3
# 12595.jpg: train=6, output=3
# 12596.jpg: train=4, output=5
# 12597.jpg: train=3, output=4
# 12598.jpg: train=5, output=1
# 12599.jpg: train=3, output=4
# 12600.jpg: train=5, output=1
# 12601.jpg: train=2, output=1
# 12602.jpg: train=6, output=7
# 12603.jpg: train=6, output=7
# 12604.jpg: train=4, output=4
# 12605.jpg: train=6, output=6
# 12606.jpg: train=3, output=2
# 12607.jpg: train=3, output=1
# 12608.jpg: train=6, output=6
# 12610.jpg: train=3, output=2
# 12611.jpg: train=3, output=3
# 12612.jpg: train=4, output=3
# 12614.jpg: train=3, output=2
# 12615.jpg: train=2, output=2
# 12616.jpg: train=6, output=4
# 12618.jpg: train=4, output=1
# 12619.jpg: train=4, output=2
# 12620.jpg: train=4, output=4
# 12621.jpg: train=3, output=2
# 12622.jpg: train=3, output=2
# 12623.jpg: train=3, output=3
# 12625.jpg: train=3, output=6
# 12628.jpg: train=5, output=7
# 12629.jpg: train=2, output=0
# 12630.jpg: train=4, output=2
# 12633.jpg: train=5, output=2
# 12635.jpg: train=6, output=3
# 12640.jpg: train=2, output=1
# 12641.jpg: train=4, output=3
# 12642.jpg: train=11, output=5
# 12643.jpg: train=16, output=10
# 12645.jpg: train=6, output=1
# 12647.jpg: train=7, output=3
# 12648.jpg: train=3, output=2
# 12649.jpg: train=7, output=2
# 12651.jpg: train=7, output=6
# 12653.jpg: train=3, output=3
# 12654.jpg: train=7, output=1
# 12656.jpg: train=9, output=6
# 12657.jpg: train=3, output=2
# 12659.jpg: train=3, output=4
# 12660.jpg: train=31, output=20
# 12661.jpg: train=23, output=9
# 12662.jpg: train=8, output=4
# 12664.jpg: train=6, output=2
# 12665.jpg: train=24, output=14
# 12669.jpg: train=4, output=4
# 12670.jpg: train=7, output=8
# 12671.jpg: train=3, output=3
# 12674.jpg: train=3, output=3
# 12675.jpg: train=8, output=7
# 12676.jpg: train=6, output=5
# 12677.jpg: train=6, output=2
# 12680.jpg: train=3, output=3
# 12682.jpg: train=3, output=5
# 12683.jpg: train=9, output=4
# 12685.jpg: train=9, output=6
# 12686.jpg: train=5, output=5
# 12687.jpg: train=5, output=2
# 12688.jpg: train=4, output=3
# 12690.jpg: train=3, output=2
# 12691.jpg: train=3, output=3
# 12692.jpg: train=3, output=4
# 12693.jpg: train=3, output=1
# 12694.jpg: train=3, output=2
# 12695.jpg: train=3, output=2
# 12696.jpg: train=3, output=1
# 12697.jpg: train=2, output=0
# 12698.jpg: train=4, output=1
# 12699.jpg: train=2, output=0
# 12701.jpg: train=4, output=2
# 12702.jpg: train=4, output=5
# 12704.jpg: train=7, output=3
# 12705.jpg: train=4, output=3
# 12706.jpg: train=2, output=2
# 12707.jpg: train=5, output=6
# 12708.jpg: train=5, output=3
# 12709.jpg: train=5, output=4
# 12711.jpg: train=4, output=3
# 12712.jpg: train=5, output=1
# 12714.jpg: train=5, output=1
# 12715.jpg: train=5, output=5
# 12716.jpg: train=5, output=4
# 12717.jpg: train=5, output=1
# 12719.jpg: train=2, output=2
# 12720.jpg: train=9, output=6
# 12721.jpg: train=4, output=3
# 12722.jpg: train=8, output=4
# 12723.jpg: train=7, output=2
# 12724.jpg: train=5, output=5
# 12725.jpg: train=4, output=5
# 12726.jpg: train=14, output=13
# 12727.jpg: train=14, output=7
# 12728.jpg: train=14, output=15
# 12730.jpg: train=6, output=4
# 12731.jpg: train=4, output=3
# 12732.jpg: train=4, output=7
# 12733.jpg: train=4, output=2
# 12734.jpg: train=4, output=1
# 12735.jpg: train=4, output=1
# 12740.jpg: train=2, output=5
# 12741.jpg: train=4, output=5
# 12742.jpg: train=4, output=4
# 12744.jpg: train=77, output=15
# 12745.jpg: train=9, output=6
# 12746.jpg: train=20, output=4
# 12747.jpg: train=2, output=1
# 12748.jpg: train=8, output=3
# 12749.jpg: train=3, output=0
# 12750.jpg: train=4, output=4
# 12753.jpg: train=4, output=2
# 12755.jpg: train=3, output=1
# 12757.jpg: train=4, output=3
# 12759.jpg: train=4, output=1
# 12760.jpg: train=4, output=1
# 12763.jpg: train=5, output=3
# 12764.jpg: train=5, output=4
# 12766.jpg: train=3, output=3
# 12767.jpg: train=5, output=6
# 12768.jpg: train=3, output=3
# 12769.jpg: train=3, output=3
# 12774.jpg: train=2, output=0
# 12775.jpg: train=2, output=0
# 12776.jpg: train=2, output=0
# 12777.jpg: train=2, output=3
# 12778.jpg: train=2, output=0
# 12779.jpg: train=1, output=0
# 12780.jpg: train=2, output=1
# 12782.jpg: train=5, output=7
# 12783.jpg: train=4, output=5
# 12785.jpg: train=4, output=5
# 12786.jpg: train=4, output=4
# 12789.jpg: train=4, output=6
# 12790.jpg: train=1, output=1
# 12791.jpg: train=5, output=5
# 12792.jpg: train=6, output=6
# 12793.jpg: train=4, output=3
# 12794.jpg: train=6, output=4
# 12795.jpg: train=3, output=3
# 12796.jpg: train=3, output=3
# 12799.jpg: train=5, output=6
# 12801.jpg: train=2, output=2
# 12802.jpg: train=2, output=3
# 12803.jpg: train=2, output=2
# 12804.jpg: train=3, output=1
# 12805.jpg: train=1, output=1
# 12808.jpg: train=13, output=3
# 12809.jpg: train=2, output=2
# 12810.jpg: train=7, output=8
# 12813.jpg: train=3, output=1
# 12814.jpg: train=4, output=4
# 12815.jpg: train=5, output=3
# 12816.jpg: train=4, output=3
# 12817.jpg: train=3, output=4
# 12819.jpg: train=5, output=2
# 12820.jpg: train=2, output=3
# 12823.jpg: train=5, output=4
# 12824.jpg: train=2, output=1
# 12825.jpg: train=3, output=5
# 12826.jpg: train=2, output=3
# 12828.jpg: train=4, output=2
# 12829.jpg: train=3, output=1
# 12830.jpg: train=4, output=5
# 12832.jpg: train=4, output=3
# 12836.jpg: train=7, output=3
# 12837.jpg: train=6, output=2
# 12838.jpg: train=4, output=5
# 12843.jpg: train=6, output=5
# 12845.jpg: train=7, output=7
# 12846.jpg: train=3, output=3
# 12847.jpg: train=5, output=4
# 12849.jpg: train=2, output=3
# 12850.jpg: train=3, output=3
# 12851.jpg: train=2, output=3
# 12853.jpg: train=2, output=4
# 12854.jpg: train=2, output=1
# 12855.jpg: train=4, output=4
# 12856.jpg: train=2, output=0
# 12857.jpg: train=2, output=1
# 12860.jpg: train=3, output=1
# 12861.jpg: train=4, output=1
# 12862.jpg: train=5, output=2
# 12863.jpg: train=5, output=2
# 12864.jpg: train=6, output=2
# 12865.jpg: train=4, output=2
# 12866.jpg: train=4, output=3
# 12867.jpg: train=9, output=10
# 12868.jpg: train=8, output=4
# 12870.jpg: train=2, output=4
# 12871.jpg: train=10, output=5
# 12872.jpg: train=2, output=0
# 12873.jpg: train=3, output=2
# 12874.jpg: train=3, output=2
# 12875.jpg: train=3, output=1
# 12876.jpg: train=3, output=2
# 12879.jpg: train=7, output=1
# 12881.jpg: train=3, output=2
# 12882.jpg: train=4, output=2
# 12883.jpg: train=3, output=4
# 12884.jpg: train=4, output=5
# 12885.jpg: train=4, output=3
# 12887.jpg: train=4, output=2
# 12890.jpg: train=3, output=2
# 12892.jpg: train=5, output=5
# 12893.jpg: train=3, output=4
# 12894.jpg: train=8, output=6
# 12895.jpg: train=11, output=7
# 12897.jpg: train=5, output=5
# 12898.jpg: train=4, output=3
# 12899.jpg: train=4, output=5
# 12900.jpg: train=4, output=5
# 12902.jpg: train=4, output=4
# 12903.jpg: train=4, output=4
# 12904.jpg: train=4, output=4
# 12907.jpg: train=4, output=2
# 12909.jpg: train=4, output=4
# 12910.jpg: train=4, output=2
# 12911.jpg: train=4, output=2
# 12914.jpg: train=2, output=3
# 12916.jpg: train=3, output=2
# 12918.jpg: train=5, output=2
# 12921.jpg: train=3, output=4
# 12922.jpg: train=6, output=4
# 12923.jpg: train=6, output=2
# 12924.jpg: train=6, output=4
# 12925.jpg: train=2, output=2
# 12926.jpg: train=2, output=3
# 12929.jpg: train=2, output=2
# 12931.jpg: train=2, output=0
# 12933.jpg: train=2, output=0
# 12934.jpg: train=7, output=5
# 12935.jpg: train=2, output=3
# 12937.jpg: train=7, output=8
# 12938.jpg: train=2, output=3
# 12941.jpg: train=3, output=3
# 12942.jpg: train=7, output=7
# 12943.jpg: train=14, output=1
# 12944.jpg: train=13, output=2
# 12945.jpg: train=11, output=3
# 12947.jpg: train=3, output=1
# 12949.jpg: train=4, output=4
# 12950.jpg: train=10, output=4
# 12951.jpg: train=6, output=4
# 12953.jpg: train=13, output=7
# 12955.jpg: train=3, output=3
# 12956.jpg: train=2, output=3
# 12957.jpg: train=2, output=1
# 12958.jpg: train=3, output=1
# 12961.jpg: train=2, output=0
# 12962.jpg: train=2, output=2
# 12963.jpg: train=2, output=0
# 12964.jpg: train=4, output=2
# 12965.jpg: train=3, output=2
# 12967.jpg: train=7, output=6
# 12969.jpg: train=2, output=1
# 12970.jpg: train=2, output=0
# 12972.jpg: train=3, output=2
# 12973.jpg: train=2, output=1
# 12974.jpg: train=3, output=2
# 12976.jpg: train=7, output=2
# 12977.jpg: train=7, output=0
# 12978.jpg: train=6, output=8
# 12980.jpg: train=5, output=5
# 12981.jpg: train=6, output=5
# 12983.jpg: train=5, output=3
# 12986.jpg: train=3, output=2
# 12987.jpg: train=4, output=3
# 12988.jpg: train=4, output=4
# 12990.jpg: train=4, output=4
# 12991.jpg: train=4, output=4
# 12992.jpg: train=5, output=4
# 12993.jpg: train=5, output=6
# 12997.jpg: train=12, output=6
# 12998.jpg: train=2, output=0
# 12999.jpg: train=6, output=4
# 13000.jpg: train=5, output=3
# 13001.jpg: train=8, output=9
# 13002.jpg: train=3, output=0
# 13003.jpg: train=6, output=5
# 13004.jpg: train=6, output=9
# 13005.jpg: train=6, output=5
# 13006.jpg: train=6, output=5
# 13007.jpg: train=4, output=1
# 13008.jpg: train=4, output=6
# 13009.jpg: train=9, output=7
# 13012.jpg: train=10, output=8
# 13016.jpg: train=28, output=16
# 13017.jpg: train=18, output=3
# 13018.jpg: train=4, output=1
# 13019.jpg: train=3, output=4
# 13021.jpg: train=3, output=3
# 13022.jpg: train=3, output=3
# 13023.jpg: train=7, output=4
# 13025.jpg: train=5, output=0
# 13026.jpg: train=11, output=9
# 13028.jpg: train=9, output=4
# 13030.jpg: train=4, output=3
# 13032.jpg: train=9, output=5
# 13033.jpg: train=6, output=5
# 13034.jpg: train=6, output=4
# 13035.jpg: train=13, output=2
# 13036.jpg: train=11, output=1
# 13037.jpg: train=11, output=3
# 13039.jpg: train=9, output=3
# 13047.jpg: train=3, output=0
# 13049.jpg: train=4, output=0
# 13050.jpg: train=17, output=2
# 13051.jpg: train=3, output=1
# 13053.jpg: train=6, output=6
# 13055.jpg: train=4, output=5
# 13056.jpg: train=5, output=5
# 13057.jpg: train=2, output=1
# 13058.jpg: train=3, output=1
# 13059.jpg: train=3, output=1
# 13060.jpg: train=6, output=6
# 13061.jpg: train=4, output=4
# 13062.jpg: train=3, output=4
# 13063.jpg: train=2, output=1
# 13064.jpg: train=3, output=4
# 13067.jpg: train=2, output=1
# 13068.jpg: train=3, output=4
# 13069.jpg: train=3, output=0
# 13070.jpg: train=3, output=4
# 13071.jpg: train=3, output=4
# 13072.jpg: train=3, output=1
# 13075.jpg: train=7, output=0
# 13076.jpg: train=4, output=3
# 13077.jpg: train=5, output=7
# 13078.jpg: train=5, output=4
# 13079.jpg: train=4, output=0
# 13080.jpg: train=3, output=4
# 13081.jpg: train=4, output=6
# 13083.jpg: train=4, output=4
# 13084.jpg: train=4, output=4
# 13085.jpg: train=2, output=2
# 13086.jpg: train=4, output=2
# 13088.jpg: train=8, output=3
# 13089.jpg: train=8, output=2
# 13090.jpg: train=8, output=2
# 13093.jpg: train=5, output=4
# 13094.jpg: train=4, output=4
# 13095.jpg: train=4, output=4
# 13097.jpg: train=10, output=1
# 13098.jpg: train=8, output=3
# 13099.jpg: train=8, output=5
# 13100.jpg: train=5, output=7
# 13101.jpg: train=4, output=6
# 13102.jpg: train=4, output=5
# 13103.jpg: train=2, output=5
# 13104.jpg: train=5, output=4
# 13106.jpg: train=4, output=2
# 13107.jpg: train=4, output=2
# 13108.jpg: train=2, output=2
# 13109.jpg: train=2, output=3
# 13110.jpg: train=2, output=1
# 13111.jpg: train=6, output=6
# 13112.jpg: train=2, output=2
# 13114.jpg: train=2, output=4
# 13115.jpg: train=2, output=2
# 13116.jpg: train=2, output=2
# 13117.jpg: train=2, output=0
# 13122.jpg: train=2, output=2
# 13124.jpg: train=4, output=2
# 13125.jpg: train=2, output=1
# 13126.jpg: train=5, output=6
# 13127.jpg: train=9, output=1
# 13129.jpg: train=9, output=6
# 13130.jpg: train=9, output=9
# 13135.jpg: train=3, output=4
# 13136.jpg: train=7, output=6
# 13139.jpg: train=4, output=4
# 13140.jpg: train=4, output=4
# 13142.jpg: train=4, output=1
# 13143.jpg: train=5, output=3
# 13144.jpg: train=3, output=2
# 13146.jpg: train=2, output=2
# 13148.jpg: train=5, output=3
# 13149.jpg: train=6, output=2
# 13151.jpg: train=6, output=4
# 13152.jpg: train=4, output=4
# 13153.jpg: train=3, output=1
# 13154.jpg: train=3, output=1
# 13155.jpg: train=5, output=3
# 13156.jpg: train=6, output=2
# 13157.jpg: train=5, output=3
# 13160.jpg: train=7, output=3
# 13161.jpg: train=4, output=4
# 13162.jpg: train=3, output=2
# 13163.jpg: train=4, output=4
# 13164.jpg: train=5, output=5
# 13166.jpg: train=5, output=4
# 13167.jpg: train=4, output=0
# 13168.jpg: train=4, output=0
# 13169.jpg: train=6, output=4
# 13172.jpg: train=15, output=13
# 13173.jpg: train=8, output=5
# 13175.jpg: train=3, output=1
# 13176.jpg: train=5, output=4
# 13177.jpg: train=14, output=7
# 13179.jpg: train=7, output=4
# 13180.jpg: train=7, output=3
# 13181.jpg: train=4, output=3
# 13184.jpg: train=4, output=0
# 13185.jpg: train=6, output=4
# 13187.jpg: train=10, output=7
# 13188.jpg: train=6, output=4
# 13189.jpg: train=3, output=3
# 13191.jpg: train=1, output=1
# 13192.jpg: train=7, output=5
# 13194.jpg: train=3, output=1
# 13195.jpg: train=2, output=3
# 13196.jpg: train=3, output=0
# 13197.jpg: train=3, output=3
# 13198.jpg: train=3, output=3
# 13199.jpg: train=6, output=5
# 13200.jpg: train=2, output=1
# 13202.jpg: train=4, output=1
# 13204.jpg: train=4, output=3
# 13205.jpg: train=3, output=3
# 13206.jpg: train=3, output=3
# 13207.jpg: train=3, output=2
# 13208.jpg: train=3, output=0
# 13209.jpg: train=5, output=5
# 13210.jpg: train=2, output=0
# 13211.jpg: train=5, output=6
# 13212.jpg: train=4, output=0
# 13213.jpg: train=4, output=0
# 13214.jpg: train=4, output=2
# 13215.jpg: train=5, output=3
# 13217.jpg: train=4, output=3
# 13218.jpg: train=3, output=3
# 13220.jpg: train=3, output=3
# 13222.jpg: train=2, output=1
# 13226.jpg: train=5, output=7
# 13229.jpg: train=2, output=0
# 13230.jpg: train=4, output=5
# 13232.jpg: train=7, output=4
# 13233.jpg: train=6, output=4
# 13234.jpg: train=5, output=2
# 13235.jpg: train=2, output=2
# 13237.jpg: train=6, output=7
# 13239.jpg: train=3, output=3
# 13240.jpg: train=2, output=0
# 13241.jpg: train=2, output=1
# 13242.jpg: train=5, output=4
# 13244.jpg: train=2, output=1
# 13245.jpg: train=3, output=2
# 13247.jpg: train=4, output=4
# 13248.jpg: train=5, output=4
# 13249.jpg: train=3, output=3
# 13250.jpg: train=2, output=3
# 13253.jpg: train=2, output=4
# 13254.jpg: train=2, output=2
# 13255.jpg: train=2, output=3
# 13256.jpg: train=5, output=3
# 13257.jpg: train=4, output=4
# 13260.jpg: train=4, output=3
# 13261.jpg: train=3, output=1
# 13262.jpg: train=3, output=2
# 13263.jpg: train=4, output=1
# 13264.jpg: train=4, output=5
# 13265.jpg: train=6, output=0
# 13267.jpg: train=6, output=1
# 13269.jpg: train=9, output=1
# 13272.jpg: train=2, output=2
# 13274.jpg: train=3, output=2
# 13275.jpg: train=3, output=2
# 13278.jpg: train=3, output=2
# 13279.jpg: train=3, output=1
# 13280.jpg: train=7, output=6
# 13281.jpg: train=7, output=7
# 13282.jpg: train=7, output=3
# 13284.jpg: train=6, output=4
# 13285.jpg: train=7, output=3
# 13286.jpg: train=4, output=4
# 13288.jpg: train=17, output=15
# 13289.jpg: train=6, output=4
# 13290.jpg: train=3, output=5
# 13291.jpg: train=9, output=3
# 13292.jpg: train=2, output=0
# 13293.jpg: train=1, output=0
# 13295.jpg: train=2, output=0
# 13296.jpg: train=2, output=4
# 13297.jpg: train=2, output=3
# 13298.jpg: train=2, output=3
# 13299.jpg: train=2, output=2
# 13300.jpg: train=2, output=1
# 13302.jpg: train=6, output=5
# 13303.jpg: train=4, output=5
# 13304.jpg: train=4, output=5
# 13305.jpg: train=2, output=0
# 13306.jpg: train=4, output=2
# 13308.jpg: train=4, output=1
# 13310.jpg: train=3, output=1
# 13311.jpg: train=2, output=3
# 13312.jpg: train=3, output=1
# 13313.jpg: train=2, output=1
# 13314.jpg: train=6, output=2
# 13315.jpg: train=4, output=1
# 13317.jpg: train=5, output=3
# 13318.jpg: train=3, output=2
# 13319.jpg: train=14, output=9
# 13320.jpg: train=3, output=1
# 13321.jpg: train=5, output=3
# 13322.jpg: train=5, output=4
# 13325.jpg: train=7, output=6
# 13326.jpg: train=3, output=3
# 13327.jpg: train=9, output=4
# 13328.jpg: train=6, output=3
# 13330.jpg: train=5, output=5
# 13331.jpg: train=5, output=5
# 13334.jpg: train=7, output=6
# 13335.jpg: train=14, output=7
# 13338.jpg: train=3, output=4
# 13339.jpg: train=3, output=4
# 13341.jpg: train=3, output=1
# 13345.jpg: train=3, output=4
# 13346.jpg: train=3, output=4
# 13348.jpg: train=3, output=2
# 13352.jpg: train=3, output=2
# 13353.jpg: train=2, output=2
# 13354.jpg: train=8, output=6
# 13355.jpg: train=4, output=5
# 13357.jpg: train=22, output=13
# 13359.jpg: train=8, output=6
# 13360.jpg: train=4, output=3
# 13361.jpg: train=2, output=2
# 13362.jpg: train=3, output=0
# 13363.jpg: train=2, output=3
# 13364.jpg: train=2, output=1
# 13365.jpg: train=3, output=3
# 13367.jpg: train=2, output=3
# 13369.jpg: train=3, output=3
# 13370.jpg: train=3, output=3
# 13371.jpg: train=3, output=5
# 13372.jpg: train=3, output=2
# 13377.jpg: train=2, output=1
# 13378.jpg: train=9, output=5
# 13379.jpg: train=6, output=4
# 13380.jpg: train=10, output=6
# 13381.jpg: train=2, output=2
# 13382.jpg: train=2, output=0
# 13384.jpg: train=3, output=0
# 13385.jpg: train=7, output=1
# 13388.jpg: train=3, output=3
# 13389.jpg: train=3, output=4
# 13392.jpg: train=4, output=3
# 13393.jpg: train=3, output=4
# 13394.jpg: train=14, output=9
# 13395.jpg: train=3, output=2
# 13396.jpg: train=8, output=1
# 13397.jpg: train=5, output=5
# 13398.jpg: train=6, output=2
# 13401.jpg: train=28, output=13
# 13402.jpg: train=14, output=4
# 13403.jpg: train=7, output=8
# 13404.jpg: train=8, output=4
# 13406.jpg: train=6, output=0
# 13407.jpg: train=4, output=2
# 13409.jpg: train=8, output=2
# 13411.jpg: train=24, output=3
# 13413.jpg: train=13, output=11
# 13415.jpg: train=6, output=4
# 13416.jpg: train=12, output=8
# 13418.jpg: train=5, output=2
# 13419.jpg: train=4, output=2
# 13420.jpg: train=8, output=3
# 13421.jpg: train=6, output=3
# 13422.jpg: train=16, output=5
# 13424.jpg: train=6, output=8
# 13425.jpg: train=2, output=0
# 13426.jpg: train=2, output=0
# 13427.jpg: train=5, output=3
# 13428.jpg: train=5, output=6
# 13431.jpg: train=6, output=9
# 13434.jpg: train=5, output=3
# 13435.jpg: train=5, output=2
# 13437.jpg: train=5, output=3
# 13440.jpg: train=3, output=2
# ...
# 17417.jpg: train=3, output=3
# 17418.jpg: train=2, output=1
# 17421.jpg: train=3, output=1
# 17422.jpg: train=3, output=2
# 17423.jpg: train=3, output=3
# 17424.jpg: train=4, output=3
# 17426.jpg: train=4, output=4
# 17427.jpg: train=4, output=4
# 17428.jpg: train=3, output=1
# 17429.jpg: train=3, output=1
# 17430.jpg: train=4, output=0
# 17431.jpg: train=2, output=1
# 17433.jpg: train=5, output=3
# 17434.jpg: train=2, output=2
# 17436.jpg: train=8, output=3
# 17437.jpg: train=3, output=0
# 17438.jpg: train=5, output=6
# 17439.jpg: train=2, output=2
# 17440.jpg: train=4, output=4
# 17441.jpg: train=6, output=5
# 17442.jpg: train=6, output=6
# 17444.jpg: train=4, output=1
# 17446.jpg: train=2, output=1
# 17449.jpg: train=4, output=3
# 17451.jpg: train=6, output=5
# 17453.jpg: train=5, output=2
# 17455.jpg: train=5, output=2
# 17456.jpg: train=4, output=5
# 17457.jpg: train=3, output=2
# 17459.jpg: train=6, output=7
# 17463.jpg: train=4, output=2
# 17464.jpg: train=5, output=5
# 17465.jpg: train=3, output=3
# 17466.jpg: train=4, output=4
# 17470.jpg: train=2, output=1
# 17471.jpg: train=2, output=0
# 17472.jpg: train=4, output=0
# 17473.jpg: train=4, output=3
# 17474.jpg: train=3, output=3
# 17475.jpg: train=3, output=3
# 17476.jpg: train=3, output=2
# 17477.jpg: train=3, output=4
# 17478.jpg: train=3, output=3
# 17479.jpg: train=6, output=5
# 17480.jpg: train=3, output=3
# 17481.jpg: train=3, output=3
# 17482.jpg: train=3, output=1
# 17483.jpg: train=3, output=1
# 17484.jpg: train=3, output=4
# 17485.jpg: train=3, output=4
# 17486.jpg: train=2, output=1
# 17487.jpg: train=3, output=0
# 17488.jpg: train=4, output=4
# 17489.jpg: train=3, output=1
# 17490.jpg: train=4, output=0
# 17491.jpg: train=3, output=1
# 17495.jpg: train=3, output=2
# 17496.jpg: train=3, output=2
# 17497.jpg: train=3, output=2
# 17499.jpg: train=3, output=1
# 17501.jpg: train=1, output=3
# 17502.jpg: train=2, output=3
# 17503.jpg: train=7, output=5
# 17505.jpg: train=4, output=3
# 17506.jpg: train=3, output=2
# 17507.jpg: train=7, output=6
# 17511.jpg: train=5, output=3
# 17512.jpg: train=5, output=2
# 17513.jpg: train=5, output=3
# 17514.jpg: train=3, output=3
# 17515.jpg: train=4, output=3
# 17517.jpg: train=3, output=4
# 17518.jpg: train=4, output=0
# 17519.jpg: train=3, output=0
# 17520.jpg: train=3, output=3
# 17521.jpg: train=3, output=1
# 17522.jpg: train=4, output=4
# 17523.jpg: train=3, output=3
# 17524.jpg: train=2, output=2
# 17525.jpg: train=3, output=2
# 17527.jpg: train=4, output=4
# 17528.jpg: train=3, output=1
# 17529.jpg: train=4, output=5
# 17530.jpg: train=4, output=4
# 17531.jpg: train=4, output=2
# 17532.jpg: train=3, output=1
# 17533.jpg: train=4, output=0
# 17534.jpg: train=4, output=5
# 17537.jpg: train=4, output=2
# 17539.jpg: train=4, output=4
# 17540.jpg: train=4, output=2
# 17541.jpg: train=3, output=2
# 17544.jpg: train=3, output=2
# 17546.jpg: train=4, output=6
# 17547.jpg: train=4, output=3
# 17548.jpg: train=4, output=4
# 17549.jpg: train=4, output=1
# 17550.jpg: train=5, output=1
# 17551.jpg: train=5, output=2
# 17552.jpg: train=3, output=1
# 17553.jpg: train=6, output=5
# 17554.jpg: train=3, output=4
# 17555.jpg: train=5, output=5
# 17556.jpg: train=5, output=4
# 17557.jpg: train=3, output=2
# 17558.jpg: train=3, output=3
# 17559.jpg: train=3, output=2
# 17562.jpg: train=4, output=5
# 17563.jpg: train=5, output=6
# 17564.jpg: train=7, output=3
# 17565.jpg: train=6, output=2
# 17567.jpg: train=3, output=0
# 17568.jpg: train=3, output=4
# 17569.jpg: train=5, output=5
# 17570.jpg: train=6, output=1
# 17571.jpg: train=5, output=1
# 17572.jpg: train=4, output=1
# 17575.jpg: train=4, output=0
# 17576.jpg: train=9, output=0
# 17579.jpg: train=9, output=0
# 17580.jpg: train=7, output=4
# 17581.jpg: train=3, output=4
# 17582.jpg: train=3, output=3
# 17583.jpg: train=3, output=4
# 17584.jpg: train=6, output=2
# 17586.jpg: train=10, output=6
# 17587.jpg: train=12, output=4
# 17590.jpg: train=4, output=0
# 17593.jpg: train=3, output=2
# 17594.jpg: train=4, output=3
# 17595.jpg: train=4, output=4
# 17596.jpg: train=9, output=0
# 17597.jpg: train=4, output=4
# 17598.jpg: train=3, output=2
# 17600.jpg: train=6, output=7
# 17601.jpg: train=4, output=6
# 17603.jpg: train=5, output=7
# 17604.jpg: train=1, output=1
# 17605.jpg: train=3, output=7
# 17606.jpg: train=6, output=4
# 17607.jpg: train=2, output=2
# 17608.jpg: train=2, output=0
# 17609.jpg: train=6, output=6
# 17610.jpg: train=4, output=6
# 17611.jpg: train=3, output=2
# 17612.jpg: train=8, output=4
# 17613.jpg: train=3, output=7
# 17616.jpg: train=3, output=3
# 17617.jpg: train=3, output=1
# 17618.jpg: train=3, output=0
# 17619.jpg: train=3, output=0
# 17620.jpg: train=3, output=1
# 17621.jpg: train=3, output=0
# 17622.jpg: train=3, output=2
# 17623.jpg: train=3, output=4
# 17627.jpg: train=3, output=0
# 17628.jpg: train=3, output=2
# 17629.jpg: train=3, output=4
# 17631.jpg: train=3, output=2
# 17632.jpg: train=3, output=2
# 17634.jpg: train=3, output=5
# 17635.jpg: train=3, output=3
# 17636.jpg: train=3, output=3
# 17637.jpg: train=3, output=3
# 17638.jpg: train=3, output=2
# 17639.jpg: train=3, output=3
# 17640.jpg: train=3, output=2
# 17641.jpg: train=3, output=4
# 17643.jpg: train=3, output=0
# 17644.jpg: train=3, output=6
# 17645.jpg: train=3, output=2
# 17646.jpg: train=6, output=5
# 17647.jpg: train=4, output=2
# 17649.jpg: train=4, output=1
# 17651.jpg: train=3, output=3
# 17652.jpg: train=5, output=6
# 17655.jpg: train=7, output=5
# 17658.jpg: train=4, output=4
# 17659.jpg: train=3, output=3
# 17660.jpg: train=3, output=2
# 17661.jpg: train=3, output=2
# 17662.jpg: train=3, output=2
# 17664.jpg: train=3, output=5
# 17666.jpg: train=3, output=1
# 17668.jpg: train=3, output=3
# 17669.jpg: train=3, output=4
# 17670.jpg: train=3, output=1
# 17672.jpg: train=3, output=0
# 17673.jpg: train=3, output=1
# 17677.jpg: train=3, output=0
# 17679.jpg: train=3, output=1
# 17680.jpg: train=3, output=2
# 17682.jpg: train=3, output=1
# 17683.jpg: train=3, output=1
# 17684.jpg: train=3, output=2
# 17685.jpg: train=3, output=3
# 17686.jpg: train=3, output=0
# 17689.jpg: train=3, output=3
# 17691.jpg: train=3, output=2
# 17692.jpg: train=3, output=3
# 17695.jpg: train=3, output=4
# 17698.jpg: train=3, output=1
# 17700.jpg: train=3, output=3
# 17702.jpg: train=5, output=4
# 17703.jpg: train=3, output=4
# 17704.jpg: train=3, output=3
# 17707.jpg: train=3, output=4
# 17708.jpg: train=3, output=4
# 17710.jpg: train=3, output=4
# 17711.jpg: train=3, output=4
# 17712.jpg: train=14, output=10
# 17714.jpg: train=5, output=6
# 17717.jpg: train=4, output=4
# 17719.jpg: train=4, output=5
# 17720.jpg: train=4, output=4
# 17721.jpg: train=4, output=4
# 17722.jpg: train=4, output=5
# 17723.jpg: train=9, output=3
# 17724.jpg: train=4, output=2
# 17726.jpg: train=4, output=4
# 17727.jpg: train=4, output=3
# 17728.jpg: train=5, output=6
# 17729.jpg: train=2, output=0
# 17731.jpg: train=5, output=1
# 17732.jpg: train=4, output=1
# 17734.jpg: train=3, output=2
# 17735.jpg: train=3, output=3
# 17737.jpg: train=4, output=0
# 17738.jpg: train=7, output=0
# 17739.jpg: train=6, output=1
# 17740.jpg: train=8, output=0
# 17741.jpg: train=5, output=1
# 17742.jpg: train=2, output=2
# 17743.jpg: train=2, output=2
# 17745.jpg: train=3, output=1
# 17746.jpg: train=2, output=0
# 17748.jpg: train=20, output=2
# 17749.jpg: train=3, output=3
# 17750.jpg: train=4, output=1
# 17752.jpg: train=3, output=2
# 17753.jpg: train=2, output=1
# 17754.jpg: train=4, output=4
# 17756.jpg: train=8, output=8
# 17757.jpg: train=4, output=5
# 17758.jpg: train=3, output=1
# 17759.jpg: train=4, output=3
# 17761.jpg: train=5, output=4
# 17762.jpg: train=3, output=2
# 17763.jpg: train=3, output=4
# 17764.jpg: train=7, output=2
# 17766.jpg: train=3, output=4
# 17767.jpg: train=4, output=3
# 17769.jpg: train=3, output=1
# 17770.jpg: train=3, output=5
# 17774.jpg: train=4, output=0
# 17776.jpg: train=2, output=0
# 17777.jpg: train=2, output=1
# 17779.jpg: train=4, output=6
# 17781.jpg: train=2, output=2
# 17784.jpg: train=2, output=1
# 17786.jpg: train=2, output=1
# 17787.jpg: train=2, output=4
# 17788.jpg: train=2, output=3
# 17789.jpg: train=2, output=3
# 17792.jpg: train=3, output=3
# 17793.jpg: train=3, output=5
# 17794.jpg: train=4, output=3
# 17795.jpg: train=4, output=2
# 17796.jpg: train=3, output=4
# 17798.jpg: train=2, output=2
# 17799.jpg: train=4, output=4
# 17800.jpg: train=4, output=3
# 17802.jpg: train=3, output=2
# 17804.jpg: train=2, output=1
# 17806.jpg: train=4, output=2
# 17807.jpg: train=2, output=3
# 17808.jpg: train=2, output=0
# 17809.jpg: train=4, output=3
# 17811.jpg: train=2, output=0
# 17812.jpg: train=2, output=3
# 17814.jpg: train=2, output=2
# 17815.jpg: train=2, output=0
# 17816.jpg: train=2, output=5
# 17817.jpg: train=2, output=2
# 17818.jpg: train=2, output=2
# 17819.jpg: train=2, output=0
# 17820.jpg: train=2, output=3
# 17822.jpg: train=3, output=3
# 17826.jpg: train=3, output=2
# 17828.jpg: train=2, output=1
# 17829.jpg: train=2, output=1
# 17831.jpg: train=2, output=1
# 17832.jpg: train=2, output=1
# 17833.jpg: train=2, output=2
# 17834.jpg: train=2, output=1
# 17836.jpg: train=5, output=4
# 17837.jpg: train=3, output=0
# 17838.jpg: train=4, output=5
# 17841.jpg: train=2, output=1
# 17842.jpg: train=3, output=2
# 17843.jpg: train=3, output=3
# 17844.jpg: train=6, output=3
# 17845.jpg: train=2, output=1
# 17851.jpg: train=4, output=0
# 17852.jpg: train=3, output=1
# 17853.jpg: train=11, output=2
# 17854.jpg: train=4, output=1
# 17857.jpg: train=2, output=0
# 17858.jpg: train=5, output=2
# 17859.jpg: train=3, output=3
# 17862.jpg: train=5, output=4
# 17863.jpg: train=4, output=6
# 17864.jpg: train=4, output=5
# 17865.jpg: train=7, output=5
# 17866.jpg: train=4, output=5
# 17867.jpg: train=4, output=3
# 17868.jpg: train=4, output=3
# 17869.jpg: train=5, output=7
# 17871.jpg: train=3, output=2
# 17872.jpg: train=2, output=3
# 17873.jpg: train=3, output=3
# 17875.jpg: train=5, output=7
# 17876.jpg: train=2, output=0
# 17878.jpg: train=5, output=6
# 17879.jpg: train=6, output=6
# 17880.jpg: train=3, output=3
# 17881.jpg: train=3, output=4
# 17882.jpg: train=5, output=2
# 17883.jpg: train=7, output=5
# 17885.jpg: train=3, output=4
# 17886.jpg: train=3, output=4
# 17887.jpg: train=7, output=2
# 17888.jpg: train=5, output=5
# 17889.jpg: train=3, output=1
# 17890.jpg: train=13, output=13
# 17894.jpg: train=1, output=1
# 17895.jpg: train=5, output=5
# 17896.jpg: train=5, output=4
# 17897.jpg: train=5, output=6
# 17899.jpg: train=5, output=5
# 17900.jpg: train=2, output=1
# 17902.jpg: train=2, output=2
# 17903.jpg: train=2, output=3
# 17906.jpg: train=2, output=3
# 17907.jpg: train=9, output=3
# 17908.jpg: train=3, output=2
# 17909.jpg: train=4, output=2
# 17913.jpg: train=6, output=6
# 17914.jpg: train=3, output=3
# 17916.jpg: train=7, output=4
# 17918.jpg: train=3, output=0
# 17920.jpg: train=1, output=1
# 17921.jpg: train=1, output=2
# 17922.jpg: train=5, output=1
# 17924.jpg: train=5, output=3
# 17926.jpg: train=3, output=2
# 17927.jpg: train=2, output=2
# 17928.jpg: train=2, output=1
# 17929.jpg: train=4, output=6
# 17930.jpg: train=10, output=7
# 17931.jpg: train=6, output=6
# 17932.jpg: train=5, output=3
# 17936.jpg: train=4, output=5
# 17937.jpg: train=2, output=4
# 17938.jpg: train=3, output=1
# 17939.jpg: train=2, output=1
# 17940.jpg: train=4, output=4
# 17941.jpg: train=4, output=5
# 17943.jpg: train=3, output=4
# 17946.jpg: train=3, output=3
# 17947.jpg: train=3, output=3
# 17948.jpg: train=4, output=3
# 17949.jpg: train=2, output=4
# 17950.jpg: train=3, output=2
# 17951.jpg: train=3, output=2
# 17954.jpg: train=3, output=4
# 17956.jpg: train=3, output=3
# 17957.jpg: train=1, output=0
# 17958.jpg: train=1, output=0
# 17959.jpg: train=1, output=0
# 17961.jpg: train=4, output=2
# 17963.jpg: train=4, output=4
# 17964.jpg: train=2, output=2
# 17965.jpg: train=4, output=5
# 17966.jpg: train=6, output=4
# 17967.jpg: train=3, output=2
# 17970.jpg: train=3, output=2
# 17971.jpg: train=2, output=3
# 17972.jpg: train=3, output=5
# 17973.jpg: train=5, output=2
# 17974.jpg: train=2, output=2
# 17975.jpg: train=6, output=3
# 17976.jpg: train=5, output=0
# 17977.jpg: train=5, output=4
# 17978.jpg: train=4, output=2
# 17980.jpg: train=3, output=3
# 17983.jpg: train=3, output=2
# 17984.jpg: train=2, output=2
# 17985.jpg: train=2, output=3
# 17988.jpg: train=2, output=2
# 17989.jpg: train=2, output=1
# 17990.jpg: train=2, output=0
# 17993.jpg: train=2, output=1
# 17995.jpg: train=2, output=1
# 17996.jpg: train=2, output=1
# 17997.jpg: train=2, output=2
# 17999.jpg: train=2, output=0
# 18000.jpg: train=2, output=2
# 18001.jpg: train=3, output=4
# 18006.jpg: train=2, output=1
# 18007.jpg: train=3, output=2
# 18008.jpg: train=2, output=4
# 18009.jpg: train=3, output=3
# 18010.jpg: train=3, output=0
# 18011.jpg: train=4, output=3
# 18012.jpg: train=4, output=5
# 18015.jpg: train=3, output=1
# 18016.jpg: train=3, output=0
# 18018.jpg: train=2, output=1
# 18020.jpg: train=1, output=1
# 18021.jpg: train=4, output=3
# 18023.jpg: train=4, output=4
# 18024.jpg: train=5, output=5
# 18025.jpg: train=5, output=3
# 18027.jpg: train=6, output=4
# 18028.jpg: train=4, output=2
# 18029.jpg: train=5, output=3
# 18032.jpg: train=3, output=3
# 18033.jpg: train=3, output=4
# 18035.jpg: train=5, output=5
# 18036.jpg: train=4, output=4
# 18037.jpg: train=3, output=2
# 18040.jpg: train=4, output=5
# 18041.jpg: train=3, output=0
# 18042.jpg: train=3, output=3
# 18043.jpg: train=3, output=1
# 18044.jpg: train=3, output=3
# 18045.jpg: train=3, output=1
# 18047.jpg: train=5, output=1
# 18049.jpg: train=3, output=3
# 18050.jpg: train=6, output=5
# 18051.jpg: train=4, output=4
# 18052.jpg: train=2, output=0
# 18054.jpg: train=2, output=2
# 18055.jpg: train=2, output=3
# 18056.jpg: train=5, output=1
# 18058.jpg: train=3, output=6
# 18059.jpg: train=3, output=2
# 18060.jpg: train=5, output=3
# 18063.jpg: train=5, output=5
# 18064.jpg: train=2, output=1
# 18065.jpg: train=6, output=5
# 18068.jpg: train=3, output=2
# 18069.jpg: train=4, output=7
# 18071.jpg: train=4, output=6
# 18072.jpg: train=4, output=3
# 18075.jpg: train=6, output=3
# 18076.jpg: train=3, output=1
# 18077.jpg: train=2, output=3
# 18078.jpg: train=2, output=2
# 18079.jpg: train=2, output=2
# 18081.jpg: train=3, output=0
# 18082.jpg: train=3, output=2
# 18083.jpg: train=5, output=3
# 18084.jpg: train=4, output=9
# 18085.jpg: train=5, output=4
# 18086.jpg: train=6, output=3
# 18087.jpg: train=6, output=6
# 18088.jpg: train=6, output=4
# 18089.jpg: train=6, output=5
# 18090.jpg: train=6, output=1
# 18091.jpg: train=6, output=2
# 18092.jpg: train=6, output=6
# 18093.jpg: train=6, output=8
# 18094.jpg: train=6, output=3
# 18095.jpg: train=4, output=1
# 18096.jpg: train=6, output=1
# 18097.jpg: train=6, output=0
# 18098.jpg: train=4, output=2
# 18099.jpg: train=5, output=0
# 18100.jpg: train=5, output=2
# 18103.jpg: train=5, output=3
# 18105.jpg: train=5, output=1
# 18107.jpg: train=6, output=4
# 18109.jpg: train=6, output=5
# 18110.jpg: train=6, output=7
# 18111.jpg: train=4, output=1
# 18112.jpg: train=6, output=2
# 18113.jpg: train=4, output=5
# 18115.jpg: train=2, output=2
# 18116.jpg: train=2, output=1
# 18119.jpg: train=2, output=1
# 18120.jpg: train=3, output=3
# 18121.jpg: train=3, output=3
# 18123.jpg: train=3, output=1
# 18124.jpg: train=3, output=2
# 18125.jpg: train=5, output=4
# 18127.jpg: train=3, output=3
# 18128.jpg: train=6, output=4
# 18129.jpg: train=5, output=3
# 18130.jpg: train=5, output=5
# 18131.jpg: train=5, output=3
# 18132.jpg: train=6, output=6
# 18133.jpg: train=4, output=3
# 18134.jpg: train=6, output=5
# 18136.jpg: train=5, output=2
# 18137.jpg: train=4, output=3
# 18139.jpg: train=4, output=1
# 18142.jpg: train=3, output=2
# 18143.jpg: train=3, output=4
# 18144.jpg: train=3, output=5
# 18145.jpg: train=5, output=3
# 18146.jpg: train=6, output=6
# 18147.jpg: train=4, output=0
# 18150.jpg: train=3, output=1
# 18153.jpg: train=2, output=1
# 18154.jpg: train=2, output=2
# 18155.jpg: train=4, output=4
# 18156.jpg: train=5, output=4
# 18159.jpg: train=3, output=3
# 18164.jpg: train=5, output=4
# 18165.jpg: train=3, output=2
# 18166.jpg: train=4, output=3
# 18167.jpg: train=1, output=2
# 18168.jpg: train=3, output=1
# 18169.jpg: train=3, output=4
# 18170.jpg: train=6, output=2
# 18173.jpg: train=3, output=3
# 18174.jpg: train=3, output=2
# 18175.jpg: train=3, output=1
# 18176.jpg: train=3, output=2
# 18177.jpg: train=3, output=1
# 18178.jpg: train=3, output=4
# 18180.jpg: train=6, output=0
# 18183.jpg: train=3, output=0
# 18185.jpg: train=3, output=4
# 18187.jpg: train=3, output=4
# 18188.jpg: train=4, output=2
# 18189.jpg: train=3, output=6
# 18190.jpg: train=4, output=4
# 18191.jpg: train=4, output=2
# 18192.jpg: train=8, output=4
# 18194.jpg: train=3, output=4
# 18195.jpg: train=2, output=2
# 18196.jpg: train=2, output=1
# 18200.jpg: train=4, output=1
# 18201.jpg: train=2, output=0
# 18203.jpg: train=3, output=3
# 18204.jpg: train=5, output=5
# 18205.jpg: train=8, output=6
# 18207.jpg: train=4, output=4

# %%
# Compare the headcount values for each file
same_count = 0
for counts in headcount_dict.values():
    if counts['train'] == counts['output']:
        same_count += 1

print(f'{same_count} files had the same train and output headcount values')
print(str(same_count/5733 *100)+'% of the files precisely detected correctly')
# Out:
# 1284 files had the same train and output headcount values
# 22.39665096807954% of the files precisely detected correctly

# %%
# Compare the headcount values for each file
same_count = 0
for counts in headcount_dict.values():
    if counts['train'] == counts['output'] or (counts['train'] == counts['output'] +1):
        same_count += 1

print(f'{same_count} files had output headcount values (-1), one face missing from the train headcount values')
print(str(same_count/5733 *100)+'% of the files were partially detected correctly with an possible error of maximum of 1 missing face per image file not detected')
# Out:
# 2594 files had output headcount values (-1), one face missing from the train headcount values
# 45.246816675388104% of the files were partially detected correctly with an possible error of maximum of 1 missing face per image file not detected

# %%
# Compare the headcount values for each file
same_count = 0
for counts in headcount_dict.values():
    if counts['train'] == counts['output'] or (counts['train'] == counts['output'] +1) or (counts['train'] == counts['output'] +2):
        same_count += 1

print(f'{same_count} files had output headcount values (-1), one face missing from the train headcount values')
print(str(same_count/5733 *100)+'% of the files were partially detected correctly with an possible error of  maximum 2 missing face per image file not detected')
# Out:
# 3489 files had output headcount values (-1), one face missing from the train headcount values
# 60.858189429618% of the files were partially detected correctly with an possible error of  maximum 2 missing face per image file not detected

# %%
# Create lists of true and predicted headcounts
from sklearn.metrics import f1_score
y_true = [v['train'] for v in headcount_dict.values()]
y_pred = [v['output'] for v in headcount_dict.values()]

# Calculate the F1 score
f1 = f1_score(y_true, y_pred, average='weighted')

# Print the F1 score
print(f'The F1 score is: {f1:.2f}')
# Out:
# The F1 score is: 0.24

# %% [markdown]
# This code block reads data from two CSV files, train.csv and output.csv, and writes the output to a new CSV file named output_with_percentage.csv.
#
# The code first creates a dictionary called headcount_dict to store the headcount values for each file. It then iterates over the rows in train.csv, retrieves the filename, and checks if that file exists in output.csv. If it does, the code stores the headcount values for that file in headcount_dict. If it doesn't, the code prints a message indicating that the file was not found.
#
# After the data is read from both files and stored in headcount_dict, the code calculates the percentage of faces detected for each file by dividing the output headcount by the train headcount and multiplying by 100. The resulting percentage is then written to a new CSV file called output_with_percentage.csv, along with the other data from output.csv.
#
# The csv.DictReader() and csv.DictWriter() functions are used to read and write the CSV files, respectively. The seek() function is used to reset the output file reader to the beginning of the file so that it can be read again for each filename in the train.csv file.

# %%
with open('/content/train/train.csv', 'r') as train_file, \
        open('output.csv', 'r') as output_file, \
        open('output_with_percentage.csv', 'w', newline='') as output_with_percentage_file:

    train_reader = csv.DictReader(train_file)
    output_reader = csv.DictReader(output_file)

    # Create a dictionary to store the headcount values for each file
    headcount_dict = {}

    # Iterate over the rows in the train.csv file
    for train_row in train_reader:
        # Get the filename from the train row
        filename = train_row['Name']

        # Check if the filename is in the output.csv file
        for output_row in output_reader:
            if output_row['Name'] == filename:
                # Store the headcount value for this file in the dictionary
                headcount_dict[filename] = {
                    'train': int(train_row['HeadCount']),
                    'output': int(output_row['HeadCount'])
                }

                # Reset the output reader to the beginning of the file
                output_file.seek(0)
                next(output_reader)

                # Break out of the inner loop since we found a match
                break

        # If the filename wasn't found in the output.csv file, print a message
        else:
            print(f'File {filename} not found in output.csv')

    # Calculate the percentage of faces detected for each file and write to output_with_percentage.csv
    fieldnames = ['Name', 'HeadCount', 'percentageOfFacesDetected']
    writer = csv.DictWriter(output_with_percentage_file, fieldnames=fieldnames)
    writer.writeheader()

    for row in output_reader:
        filename = row['Name']
        counts = headcount_dict.get(filename)
        if counts:
            percentage = counts['output'] / counts['train'] * 100
            row['percentageOfFacesDetected'] = percentage
            writer.writerow(row)

# %% [markdown]
# This code block reads data from a CSV file named output_with_percentage.csv and calculates the mean percentage of faces detected across all files in the CSV.
#
# The code first opens the CSV file for reading using the with statement and the csv.DictReader() function. It then extracts the values of the percentageOfFacesDetected column from each row of the CSV file and appends them to a list called percentages.
#
# After all values have been extracted, the code uses the statistics.mean() function to calculate the mean of the percentages list. The resulting mean is stored in a variable called mean_percentage.
#
# Finally, the code prints the mean percentage of faces detected using an f-string that includes the value of mean_percentage.

# %%
import statistics

# Open the output_with_percentage.csv file for reading
with open('output_with_percentage.csv', 'r') as output_file:
    output_reader = csv.DictReader(output_file)

    # Extract the values of the percentageOfFacesDetected column
    percentages = []
    for row in output_reader:
        percentages.append(float(row['percentageOfFacesDetected']))

    # Calculate the mean of the percentages
    mean_percentage = statistics.mean(percentages)

    # Print the mean percentage
    print(f"Mean percentage of faces detected: {mean_percentage}")
# Out:
# Mean percentage of faces detected: 79.12311646553822
